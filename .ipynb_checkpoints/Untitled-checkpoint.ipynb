# %%
import pandas as pd

# %%
df = pd.read_csv('mapping_df.csv')

# %%
x = int(len(df)/2)

# %%
df_1 = df.iloc[0:x]
df_2 = df.iloc[x:]

# %%
df_1.to_csv('mapping_df1.csv')
df_2.to_csv('mapping_df2.csv')
# Out:
#            month        town flat_type block       street_name storey_range  \
# 0       1/1/1990  ANG MO KIO    1 room   309  ANG MO KIO AVE 1     10 TO 12
# 1       1/1/1990  ANG MO KIO    1 room   309  ANG MO KIO AVE 1     04 TO 06
# 2       1/1/1990  ANG MO KIO    1 room   309  ANG MO KIO AVE 1     10 TO 12
# 3       1/1/1990  ANG MO KIO    1 room   309  ANG MO KIO AVE 1     07 TO 09
# 4       1/1/1990  ANG MO KIO    3 room   216  ANG MO KIO AVE 1     04 TO 06
# ...          ...         ...       ...   ...               ...          ...
# 348829  1/9/2003   WOODLANDS    4 room   701   WOODLANDS DR 40     01 TO 03
# 348830  1/9/2003   WOODLANDS    4 room   706   WOODLANDS DR 40     01 TO 03
# 348831  1/9/2003   WOODLANDS    4 room   602   WOODLANDS DR 42     01 TO 03
# 348832  1/9/2003   WOODLANDS    4 room   551   WOODLANDS DR 44     07 TO 09
# 348833  1/9/2003   WOODLANDS    4 room   551   WOODLANDS DR 44     10 TO 12
#
# ...
